# %% [markdown]
# ASCii 아트를 이용한 글자 출력

# %% [markdown]
# ASCii 대문자 출력 코드

# %%
def ASCii_art(eng):     #ASCii_art 함수 설정
    eng = eng.upper()    #입력값을 대문자로 변환
    if not eng.isalpha() or not eng.isupper(): #입력값에 알파벳이 아닌 문자가 있거나 대문자가 아니라면
        print("출력 불가능합니다. A부터 Z까지의 영어 대문자로 입력해주세요.")  
        return
      
    ASCii_art = {         #ASCii_art 딕셔너리 설정
        'A': [
            '  A  ',
            ' A A ',
            'AAAAA',
            'A   A',
            'A   A'
        ],
        'B': [
            'BBBB ',
            'B   B',
            'BBBB ',
            'B   B',
            'BBBB '
        ],
        'C': [
            ' CCCC',
            'C    ',
            'C    ',
            'C    ',
            ' CCCC'
        ],
        'D': [
            'DDDD ',
            'D   D',
            'D   D',
            'D   D',
            'DDDD '
        ],
        'E': [
            'EEEEE',
            'E    ',
            'EEE  ',
            'E    ',
            'EEEEE'
        ],
        'F': [
            'FFFFF',
            'F    ',
            'FFF  ',
            'F    ',
            'F    '
        ],
        'G': [
            ' GGGG',
            'G    ',
            'G  GG',
            'G   G',
            ' GGGG'
        ],
        ㄴ'H': [
            'H   H',
            'H   H',
            'HHHHH',
            'H   H',
            'H   H'
        ],
        'I': [
            'IIIII',
            '  I  ',
            '  I  ',
            '  I  ',
            'IIIII'
        ],
        'J': [
            'JJJJJ',
            '   J ',
            '   J ',
            'J  J ',
            ' JJ  '
        ],
        'K': [
            'K    K',
            'K  K ',
            'KK  ',
            'K  K   ',
            'K    K '
        ],
        'L': [
            'L    ',
            'L    ',
            'L    ',
            'L    ',
            'LLLLL'
        ],
        'M': [
            'M   M',
            'MM MM',
            'M M M',
            'M   M',
            'M   M'
        ],
        'N': [
            'N   N',
            'NN  N',
            'N N N',
            'N  NN',
            'N   N'
        ],
        'O': [
            ' OOO ',
            'O   O',
            'O   O',
            'O   O',
            ' OOO '
        ],
        'P': [
            'PPPP ',
            'P   P',
            'PPPP ',
            'P    ',
            'P    '
        ],
        'Q': [
            ' QQQ ',
            'Q   Q',
            'Q   Q',
            'Q  QQ',
            ' QQQ ',
            '    Q'
        ],
        'R': [
            'RRRR ',
            'R   R',
            'RRRR ',
            'R  R ',
            'R   R'
        ],
        'S': [
            ' SSSS',
            'S    ',
            ' SSS ',
            '    S',
            'SSSS '
        ],
        'T': [
            'TTTTT',
            '  T  ',
            '  T  ',
            '  T  ',
            '  T  '
        ],
        'U': [
            'U   U',
            'U   U',
            'U   U',
            'U   U',
            ' UUU '
        ],
        'V': [
            'V     V',
            'V     V',
            'V     V',
            ' V   V ',
            '  V V  '
        ],
        'W': [
            'W       W',
            'W       W',
            'W   W   W  ',
            'W   W   W  ',
            ' W  W  W   '
        ],
        'X': [
            'X     X',
            ' X   X ',
            '   X  ',
            ' X   X   ',
            'X     X  '
        ],
        'Y': [
            'Y     Y',
            ' Y   Y ',
            '  Y Y  ',
            '   Y   ',
            '   Y   '
        ],
        'Z': [
            'ZZZZZ',
            '    Z',
            '   Z ',
            '  Z  ',
            ' Z   ',
            'ZZZZZ'
        ]
    }

    for i, letter in enumerate(eng):  #eng를 i와 letter에 차례대로 입력
        if letter in ASCii_art:      #letter에 존재하는 값들이 ASCii_art 딕셔너리에 있는지 확인
            art = ASCii_art[letter]   #해당되는 아스키 아트를 ASCii_art 딕셔너리에서 불러오기 
            result = '\n'.join(art)   #출력값 줄바꾸기
            print(result)
        else:
            print("해당하는 ASCII 아트가 없습니다.")
        
        if i < len(eng) - 1:  # 각 출력값 사이에 공백 1줄 생성
            print()

# %% [markdown]
# ascii 소문자 출력 코드

# %%
def ascii_art(eng): #ascii_art 함수 설정
    eng = eng.lower()  #영어 입력값 소문자화 하기
    if not eng.isalpha() or not eng.islower():  #입력값에 알파벳이 아닌 문자가 있거나 소문자가 아니라면
        print("출력 불가능합니다. a부터 z까지의 영어 소문자로 입력해주세요.")
        return
      
    ascii_art = {         #ascii_art 딕셔너리 설정
        'a': [
            '   ',
            ' aaaa ',
            'aa   aa',
            'aa  aaaa',
            ' aaaa  aa   '
        ],
        'b': [
            'bb ',
            'bb',
            'bbbbb ',
            'bb  bb',
            ' bbbb '
        ],
        'c': [
            ' ',
            ' cccc    ',
            'cc   ',
            'cc   ',
            ' cccc'
        ],
        'd': [
            '     dd ',
            '     dd',
            '  ddddd',
            ' dd  dd',
            '  dddd '
        ],
        'e': [
            ' eeee',
            'ee  ee',
            'eeeeee',
            'ee    ',
            ' eeeee '
        ],
        'f': [
            ' fffff',
            'ff   ff',
            'ffff  ',
            'ff   ',
            'ff    '
        ],
       'g': [
            ' gggg',
            'gg  gg ',
            ' gg gg',
            '    gg',
            'ggggg'
        ],
        'h': [
            'hh',
            'hh',
            'hhhhh',
            'hh  hh',
            'hh  hh'
        ],
        'i': [
            '  ii',
            '    ',
            '  ii ',
            '  ii ',
            '  ii'
        ],
        'j': [
            '    jj',
            '    ',
            '    jj',
            'jj  jj',
            '  jj  '
        ],
        'k': [
            'kk    ',
            'kk   kk ',
            'kk kk   ',
            'kk kk ',
            'kk   kk '
        ],
        'l': [
            '  ll    ',
            '  ll  ',
            '  ll  ',
            '  ll',
            '  ll'
        ],
        'm': [
            'M   M',
            'MM MM',
            'M M M',
            'M   M',
            'M   M'
        ],
        'n': [
            ' ',
            ' nnnnn  ',
            'nn   nn  ',
            'nn   nn   ',
            'nn   nn '
        ],
        'o': [
            ' ',
            ' oooo',
            'oo  oo',
            'oo  oo',
            ' oooo '
        ],
        'p': [
            'pppppp ',
            'pp   pp   ',
            'pp pp     ',
            'pp    ',
            'pp   '
        ],
        'q': [
            ' qqq ',
            'qq  qq ',
            ' qq qq ',
            '    qq ',
            '    qq ',
            '     qqq  '
        ],
        'r': [
            '  ',
            'rr  rrr ',
            'rrrr     ',
            'rr       ',
            'rr        '
        ],
        's': [
            ' ssss',
            'ss   ',
            ' sss ',
            '   ss',
            'ssss '
        ],
        't': [
            '   tt',
            'tttttttt',
            '   tt ',
            '   tt ',
            '   ttttt '
        ],
        'u': [
            '     ',
            'uu   uu',
            'uu   uu',
            'uu   uu',
            ' uuuuu'
        ],
        'v': [
            '      ',
            'vv    vv',
            ' vv  vv',
            '  vvvv ',
            '   vv  '
        ],
        'w': [
            'ww       ww',
            'ww       ww',
            'ww   w   ww ',
            'ww  w w  ww ',
            ' www   www   '
        ],
        'x': [
            'xx    xx',
            ' xx  xx ',
            '   xx  ',
            ' xx  xx   ',
            'xx    xx  '
        ],
        'y': [
            ' ',
            ' yy   yy ',
            '   y y  ',
            '   yy    ',
            ' yy     '
        ],
        'z': [
            ' ',
            'zzzzz',
            '  zz ',
            ' zz  ',
            'zzzzz   ',
            ''
        ]
    }

    for i, letter in enumerate(eng): #eng를 i와 letter에 차례대로 입력
        if letter in ascii_art:      #letter에 존재하는 값들이 ascii_art 딕셔너리에 있는지 확인
            art = ascii_art[letter]  #해당되는 아스키 아트를 ASCii_art 딕셔너리에서 불러오기 
            result = '\n'.join(art)  #출력값 줄바꾸기
            print(result)
        else:
            print("해당하는 ASCII 아트가 없습니다.")
        
        if i < len(eng) - 1:  # 각 출력값 사이에 공백 1줄 추가하기
            print()

# %% [markdown]
# base 코드

# %%
while True:      #무한 반복 구문
  입력 = input('아스키 아트의 종류를 선택해주세요 (대문자 / 소문자) :')
  if 입력 == '대문자':  #입력값이 '대문자'이면 
    ENG = input('영어 대문자 입력 :') #아스키 코드로  변환할 영어 입력
    ASCii_art(ENG)  #입력값 (ENG)를 ASCii_art 함수에 대입
    choice = input("계속하시겠습니까? (Y/N): ")
    if choice.upper() != 'Y': #만약 대문자 Y입력 시 
        break                 #바로 위 코드 중단 후 다시 while 구문 실행 #만약 N 입력 시 전체 코드 실행 중단


  elif 입력 == '소문자':      #입력값이 '소문자'라면
    eng = input('영어 소문자 입력 :') #아스키 코드로 변환할 영어 입력
    ascii_art(eng) #입력값(eng)를 ascii_art 함수에 대입
    choice = input("계속하시겠습니까? (Y/N): ")
    if choice.upper() != 'Y': #만약 대문자 Y 입력 시 
        break                 # 바로 위 코드 중단 후 다시 while 구문 실행  #만약 N 입력 시 전체 코드 실행 중단

  else:
    print('[대문자] 또는 [소문자]로 입력해주세요.') #대문자 또는 소문자 이외의 입력값을 받을 시 print 실
# Out:
# 아스키 아트의 종류를 선택해주세요 (대문자 / 소문자) :대문자
# 영어 대문자 입력 :K
# K    K
# K  K
# KK
# K  K
# K    K
# 계속하시겠습니까? (Y/N): 김현진
